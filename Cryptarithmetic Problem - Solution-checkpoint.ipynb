# %%
import itertools


def get_value(word, substitution):
    s = 0
    factor = 1
    for letter in reversed(word):
        s += factor * substitution[letter]
        factor *= 10
    return s


def solve2(equation):
    # split equation in left and right
    left, right = equation.lower().replace(' ', '').split('=')
    # split words in left part
    left = left.split('+')
    # create list of used letters
    letters = set(right)
    for word in left:
        for letter in word:
            letters.add(letter)
    letters = list(letters)

    digits = range(10)
    for perm in itertools.permutations(digits, len(letters)):
        sol = dict(zip(letters, perm))

        if sum(get_value(word, sol) for word in left) == get_value(right, sol):
            print(' + '.join(str(get_value(word, sol)) for word in left) + " = {} (mapping: {})".format(get_value(right, sol), sol))

if __name__ == '__main__':
    print("\n Crypt Arithmetic Solution For First Example: SEND + MORE = MONEY\n")
    solve2('SEND + MORE = MONEY')
    
    print("\n Crypt Arithmetic Solution For Second Example: FATHER + MOTHER = PARENT\n")
    solve2("FATHER + MOTHER = PARENT")
    
    print("\n Crypt Arithmetic Solution For Third Example: BASE + BALL = GAMES\n")
    solve2("BASE + BALL = GAMES")
    
    #To give any other cryptarithmetic puzzle as an input to the program, do the following:

	#solve2(“your input string here: make sure to give spaces between the operator and 	equal to sign”)
# Out:
#  Crypt Arithmetic Solution For First Example: SEND + MORE = MONEY
#
# 7316 + 823 = 8139 (mapping: {'e': 3, 'o': 8, 'm': 0, 'd': 6, 'r': 2, 'n': 1, 's': 7, 'y': 9})
# 8324 + 913 = 9237 (mapping: {'e': 3, 'o': 9, 'm': 0, 'd': 4, 'r': 1, 'n': 2, 's': 8, 'y': 7})
# 6415 + 734 = 7149 (mapping: {'e': 4, 'o': 7, 'm': 0, 'd': 5, 'r': 3, 'n': 1, 's': 6, 'y': 9})
# 6419 + 724 = 7143 (mapping: {'e': 4, 'o': 7, 'm': 0, 'd': 9, 'r': 2, 'n': 1, 's': 6, 'y': 3})
# 7429 + 814 = 8243 (mapping: {'e': 4, 'o': 8, 'm': 0, 'd': 9, 'r': 1, 'n': 2, 's': 7, 'y': 3})
# 8432 + 914 = 9346 (mapping: {'e': 4, 'o': 9, 'm': 0, 'd': 2, 'r': 1, 'n': 3, 's': 8, 'y': 6})
# 9567 + 1085 = 10652 (mapping: {'e': 5, 'o': 0, 'm': 1, 'd': 7, 'r': 8, 'n': 6, 's': 9, 'y': 2})
# 6524 + 735 = 7259 (mapping: {'e': 5, 'o': 7, 'm': 0, 'd': 4, 'r': 3, 'n': 2, 's': 6, 'y': 9})
# 7531 + 825 = 8356 (mapping: {'e': 5, 'o': 8, 'm': 0, 'd': 1, 'r': 2, 'n': 3, 's': 7, 'y': 6})
# 7534 + 825 = 8359 (mapping: {'e': 5, 'o': 8, 'm': 0, 'd': 4, 'r': 2, 'n': 3, 's': 7, 'y': 9})
# 7539 + 815 = 8354 (mapping: {'e': 5, 'o': 8, 'm': 0, 'd': 9, 'r': 1, 'n': 3, 's': 7, 'y': 4})
# 8542 + 915 = 9457 (mapping: {'e': 5, 'o': 9, 'm': 0, 'd': 2, 'r': 1, 'n': 4, 's': 8, 'y': 7})
# 7643 + 826 = 8469 (mapping: {'e': 6, 'o': 8, 'm': 0, 'd': 3, 'r': 2, 'n': 4, 's': 7, 'y': 9})
# 7649 + 816 = 8465 (mapping: {'e': 6, 'o': 8, 'm': 0, 'd': 9, 'r': 1, 'n': 4, 's': 7, 'y': 5})
# 3712 + 467 = 4179 (mapping: {'e': 7, 'o': 4, 'm': 0, 'd': 2, 'r': 6, 'n': 1, 's': 3, 'y': 9})
# 3719 + 457 = 4176 (mapping: {'e': 7, 'o': 4, 'm': 0, 'd': 9, 'r': 5, 'n': 1, 's': 3, 'y': 6})
# 5731 + 647 = 6378 (mapping: {'e': 7, 'o': 6, 'm': 0, 'd': 1, 'r': 4, 'n': 3, 's': 5, 'y': 8})
# 5732 + 647 = 6379 (mapping: {'e': 7, 'o': 6, 'm': 0, 'd': 2, 'r': 4, 'n': 3, 's': 5, 'y': 9})
# 2817 + 368 = 3185 (mapping: {'e': 8, 'o': 3, 'm': 0, 'd': 7, 'r': 6, 'n': 1, 's': 2, 'y': 5})
# 2819 + 368 = 3187 (mapping: {'e': 8, 'o': 3, 'm': 0, 'd': 9, 'r': 6, 'n': 1, 's': 2, 'y': 7})
# 3821 + 468 = 4289 (mapping: {'e': 8, 'o': 4, 'm': 0, 'd': 1, 'r': 6, 'n': 2, 's': 3, 'y': 9})
# 3829 + 458 = 4287 (mapping: {'e': 8, 'o': 4, 'm': 0, 'd': 9, 'r': 5, 'n': 2, 's': 3, 'y': 7})
# 5849 + 638 = 6487 (mapping: {'e': 8, 'o': 6, 'm': 0, 'd': 9, 'r': 3, 'n': 4, 's': 5, 'y': 7})
# 6851 + 738 = 7589 (mapping: {'e': 8, 'o': 7, 'm': 0, 'd': 1, 'r': 3, 'n': 5, 's': 6, 'y': 9})
# 6853 + 728 = 7581 (mapping: {'e': 8, 'o': 7, 'm': 0, 'd': 3, 'r': 2, 'n': 5, 's': 6, 'y': 1})
#
#  Crypt Arithmetic Solution For Second Example: FATHER + MOTHER = PARENT
#
# 56743 + 196743 = 253486 (mapping: {'e': 4, 'f': 0, 'h': 7, 'm': 1, 'r': 3, 'o': 9, 'p': 2, 'n': 8, 't': 6, 'a': 5})
# 156743 + 96743 = 253486 (mapping: {'e': 4, 'f': 1, 'h': 7, 'm': 0, 'r': 3, 'o': 9, 'p': 2, 'n': 8, 't': 6, 'a': 5})
# 186753 + 296753 = 483506 (mapping: {'e': 5, 'f': 1, 'h': 7, 'm': 2, 'r': 3, 'o': 9, 'p': 4, 'n': 0, 't': 6, 'a': 8})
# 286753 + 196753 = 483506 (mapping: {'e': 5, 'f': 2, 'h': 7, 'm': 1, 'r': 3, 'o': 9, 'p': 4, 'n': 0, 't': 6, 'a': 8})
# 56873 + 196873 = 253746 (mapping: {'e': 7, 'f': 0, 'h': 8, 'm': 1, 'r': 3, 'o': 9, 'p': 2, 'n': 4, 't': 6, 'a': 5})
# 156873 + 96873 = 253746 (mapping: {'e': 7, 'f': 1, 'h': 8, 'm': 0, 'r': 3, 'o': 9, 'p': 2, 'n': 4, 't': 6, 'a': 5})
#
#  Crypt Arithmetic Solution For Third Example: BASE + BALL = GAMES
#
# 2461 + 2455 = 4916 (mapping: {'e': 1, 'm': 9, 'l': 5, 'a': 4, 'g': 0, 'b': 2, 's': 6})
# 2483 + 2455 = 4938 (mapping: {'e': 3, 'm': 9, 'l': 5, 'a': 4, 'g': 0, 'b': 2, 's': 8})
# 7483 + 7455 = 14938 (mapping: {'e': 3, 'm': 9, 'l': 5, 'a': 4, 'g': 1, 'b': 7, 's': 8})
